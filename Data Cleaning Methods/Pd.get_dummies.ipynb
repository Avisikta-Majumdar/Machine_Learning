# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2 = df[["sex","class"]]
df_dummy = pd.get_dummies(df2)
df_dummy
# Out:
#      sex_female  sex_male  class_First  class_Second  class_Third
# 0             0         1            0             0            1
# 1             1         0            1             0            0
# 2             1         0            0             0            1
# 3             1         0            1             0            0
# 4             0         1            0             0            1
# ..          ...       ...          ...           ...          ...
# 886           0         1            0             1            0
# 887           1         0            1             0            0
# 888           1         0            0             0            1
# 889           0         1            1             0            0
# 890           0         1            0             0            1
#
# [891 rows x 5 columns]

# %%
df2 = df[["sex","class"]]
#It will drop sex_female and class_First column
df_dummy1 = pd.get_dummies(df2 , drop_first=True)
df_dummy1
# Out:
#      sex_male  class_Second  class_Third
# 0           1             0            1
# 1           0             0            0
# 2           0             0            1
# 3           0             0            0
# 4           1             0            1
# ..        ...           ...          ...
# 886         1             1            0
# 887         0             0            0
# 888         0             0            1
# 889         1             0            0
# 890         1             0            1
#
# [891 rows x 3 columns]

# %%
df.drop(columns=["sex",'class'],inplace = True)
df_4 = pd.concat([df , df_dummy1])

# %%
df_4
# Out:
#      survived  pclass   age  sibsp  parch     fare embarked    who adult_male  \
# 0         0.0     3.0  22.0    1.0    0.0   7.2500        S    man       True
# 1         1.0     1.0  38.0    1.0    0.0  71.2833        C  woman      False
# 2         1.0     3.0  26.0    0.0    0.0   7.9250        S  woman      False
# 3         1.0     1.0  35.0    1.0    0.0  53.1000        S  woman      False
# 4         0.0     3.0  35.0    0.0    0.0   8.0500        S    man       True
# ..        ...     ...   ...    ...    ...      ...      ...    ...        ...
# 886       NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN        NaN
# 887       NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN        NaN
# 888       NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN        NaN
# 889       NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN        NaN
# 890       NaN     NaN   NaN    NaN    NaN      NaN      NaN    NaN        NaN
#
# ...
