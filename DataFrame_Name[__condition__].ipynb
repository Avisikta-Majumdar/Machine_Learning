# %%
#Import package
import pandas as pd
import numpy as np

# %%
#Mount your drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#  and read the csv file. Make sure you are using the correct file path
working_directory = '/content/drive/MyDrive/AlmaBetter/Module 1 : Python for Data Science/Projects & Assessments/EDA on IMDB Dataset/'
imdb = pd.read_csv(working_directory + 'imdb_data.csv')

# %%
imdb.head()
# Out:
#    id  ...   revenue
# 0   1  ...  12314651
# 1   2  ...  95149435
# 2   3  ...  13092000
# 3   4  ...  16000000
# 4   5  ...   3923970
#
# [5 rows x 23 columns]

# %%
#imdb.original_language.value_counts()

# %% [markdown]
# ## **Now I just want this rows where original_language is english(en)**
# ## To do that we have to use condition inside imdb

# %% [markdown]
# # Method 1

# %% [markdown]
# ## **Syntax :-    DataFrame_Name[Condition][[Columns names which we want]]**
#
# #### If no of columns is 1 then  DataFrame_Name[Condition][Columns_name]
#
# #### If we want more than 1 columns then use Syntax

# %%
imdb_en= imdb[imdb['original_language']=='en'][['original_language' , 'runtime']]

# %%
imdb_en.head()
# Out:
#   original_language  runtime
# 0                en     93.0
# 1                en    113.0
# 2                en    105.0
# 5                en     83.0
# 6                en     92.0

# %%
imdb_en.shape
# Out:
# (2575,)

# %%
imdb_en.value_counts()
# Out:
# original_language  runtime
# en                 100.0      92
#                    90.0       85
#                    98.0       79
#                    105.0      79
#                    95.0       78
#                               ..
#                    172.0       1
#                    159.0       1
#                    158.0       1
#                    151.0       1
#                    338.0       1
# Length: 130, dtype: int64

# %% [markdown]
# # Method 2

# %% [markdown]
# **Syntax :-**
# ## df['new column name'] = df['column name'].apply(lambda x: 'True or value for True' if (x condition) else 'False or value for False')
